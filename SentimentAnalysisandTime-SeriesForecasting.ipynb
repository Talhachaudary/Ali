# %%
# install required module
# !pip install vaderSentiment
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 979.4 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: requests in /home/yousafzai/.local/lib/python3.10/site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->vaderSentiment) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yousafzai/.local/lib/python3.10/site-packages (from requests->vaderSentiment) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests->vaderSentiment) (1.26.5)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sqlalchemy import create_engine
import mysql.connector

# Step 1: Apply sentiment analysis to the tweets data
analyzer = SentimentIntensityAnalyzer()

# Apply sentiment analysis and store results in a new column 'sentiment'
tweets_df['sentiment'] = tweets_df['tweet'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

# Verify the sentiment column has been added
print(tweets_df[['tweet', 'sentiment']].head())
print(f"Columns in tweets dataframe: {tweets_df.columns}")

# Step 2: Store the DataFrame with sentiment results in a MySQL table
# Create the SQLAlchemy engine with a connection string
db_connection_str = 'mysql+mysqlconnector://root:Root%401234@localhost:3306/Stock_DB'

# Create engine using the connection string
engine = create_engine(db_connection_str)

# Store the DataFrame with sentiment results in a MySQL table
tweets_df.to_sql('tweets_with_sentiment', con=engine, if_exists='replace', index=False)

print("Sentiment data stored in MySQL database.")
# Out:
#                                                tweet  sentiment
# 0       $AMZN Dow futures up by 100 points already 🥳     0.3818
# 1  $TSLA Daddy's drinkin' eArly tonight! Here's t...     0.0000
# 2  $AAPL We’ll been riding since last December fr...     0.0000
# 3            $TSLA happy new year, 2020, everyone🍷🎉🙏     0.7506
# 4  $TSLA haha just a collection of greats..."Mars...     0.9371
# Columns in tweets dataframe: Index(['id', 'date', 'ticker', 'tweet', 'sentiment'], dtype='object')
# Sentiment data stored in MySQL database.

# %% [markdown]
# # Time-Series Forecasting

# %%
# Install required models if not done yet
# !pip install statsmodels
# !pip install tensorflow
# !pip install scikit-learn
# !pip install seaborn

import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
import os
import glob
from sqlalchemy import create_engine
from sklearn.metrics import mean_squared_error

# Define paths to your CSV files
tweets_file = "stocktweet/stocktweet.csv"  # Replace with the path to your stock tweets CSV
stock_files_path = "stockprice/*.csv"  # Replace with the path to your stock prices folder

# MySQL connection string
db_connection_str = 'mysql+mysqlconnector://root:Root%401234@localhost:3306/Stock_DB'
engine = create_engine(db_connection_str)

# Step 1: Load tweets with sentiment from MySQL
tweets_df = pd.read_sql('SELECT * FROM tweets_with_sentiment', con=engine)

# Check if the 'sentiment' column exists
if 'sentiment' not in tweets_df.columns:
    raise KeyError("Sentiment column is missing in tweets dataframe")

# Convert the 'date' column in tweets_df to datetime
tweets_df['date'] = pd.to_datetime(tweets_df['date'], errors='coerce')

# Step 2: Load each stock price file and add ticker column
stock_dataframes = {}
for file in glob.glob(stock_files_path):
    ticker = os.path.basename(file).replace(".csv", "")
    df = pd.read_csv(file)
    df['ticker'] = ticker  # Add ticker column
    stock_dataframes[ticker] = df

# Clean stock data by ensuring the 'date' column is in datetime format
for ticker, stock_data in stock_dataframes.items():
    stock_data['date'] = pd.to_datetime(stock_data['Date'], errors='coerce')
    stock_data = stock_data[['date', 'Close', 'ticker']]  # Keep only necessary columns

    # Merge stock data with tweet sentiment data
    try:
        merged_data = pd.merge(stock_data, tweets_df[['date', 'sentiment', 'ticker']], how='left', on=['date', 'ticker'])
        stock_dataframes[ticker] = merged_data  # Update stock data with merged results
    except KeyError as e:
        print(f"KeyError while merging data for {ticker}: {e}")

# Step 3: Time series forecasting with ARIMA and LSTM

# Helper function to create and evaluate ARIMA model
def forecast_arima(df, steps=7):
    # Preparing the data for ARIMA model
    df = df[['date', 'Close']]
    df.set_index('date', inplace=True)
    df = df['Close'].dropna()
    
    # Fit ARIMA model
    model = ARIMA(df, order=(5, 1, 0))  # Adjust order based on your data
    model_fit = model.fit()

    # Forecasting
    forecast = model_fit.forecast(steps=steps)
    forecast_index = pd.date_range(df.index[-1] + timedelta(days=1), periods=steps, freq='D')
    forecast_df = pd.DataFrame(forecast, index=forecast_index, columns=['Forecast'])
    
    return forecast_df

## Helper function to create and evaluate LSTM model
def forecast_lstm(df, steps=7):
    # Normalize the data for LSTM
    df = df[['date', 'Close']]
    df.set_index('date', inplace=True)
    df = df['Close'].dropna()
    
    scaler = MinMaxScaler(feature_range=(0, 1))
    df_scaled = scaler.fit_transform(df.values.reshape(-1, 1))
    
    # Prepare data for LSTM
    X = []
    y = []
    for i in range(60, len(df_scaled)-steps):
        X.append(df_scaled[i-60:i, 0])
        y.append(df_scaled[i+steps-1, 0])
    X = np.array(X)
    y = np.array(y)
    
    # Reshaping input for LSTM [samples, time steps, features]
    X = np.reshape(X, (X.shape[0], X.shape[1], 1))
    
    # Create the LSTM model
    model = Sequential()
    model.add(LSTM(units=50, return_sequences=True, input_shape=(X.shape[1], 1)))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Train the model
    model.fit(X, y, epochs=20, batch_size=32)
    
    # Forecast for multiple days (steps)
    forecast_values = []
    last_60_days = df_scaled[-60:].reshape(1, -1)
    last_60_days = np.reshape(last_60_days, (last_60_days.shape[0], last_60_days.shape[1], 1))
    
    for _ in range(steps):
        forecast_scaled = model.predict(last_60_days)
        forecast_value = scaler.inverse_transform(forecast_scaled)[0, 0]
        forecast_values.append(forecast_value)
        
        # Update last_60_days with the latest forecasted value
        last_60_days = np.append(last_60_days[:, 1:, :], forecast_scaled.reshape(1, 1, 1), axis=1)
    
    forecast_df = pd.DataFrame(forecast_values, 
                               index=pd.date_range(df.index[-1] + timedelta(days=1), periods=steps, freq='D'), 
                               columns=['Forecast'])
    
    return forecast_df


# Step 4: Generate forecasts for each ticker

selected_tickers = list(stock_dataframes.keys())[:5]  # This limits to the first 5 stocks

for ticker in selected_tickers:
    stock_data = stock_dataframes[ticker]
    print(f"\nForecasting for {ticker} using ARIMA and LSTM:")
    
    # ARIMA forecast for 1 day, 3 days, and 7 days
    arima_forecast_1d = forecast_arima(stock_data, steps=1)
    arima_forecast_3d = forecast_arima(stock_data, steps=3)
    arima_forecast_7d = forecast_arima(stock_data, steps=7)
    
    print(f"ARIMA forecast for {ticker} (1 Day):")
    print(arima_forecast_1d)
    
    print(f"ARIMA forecast for {ticker} (3 Days):")
    print(arima_forecast_3d)
    
    print(f"ARIMA forecast for {ticker} (7 Days):")
    print(arima_forecast_7d)
    
    # LSTM forecast for 1 day, 3 days, and 7 days
    lstm_forecast_1d = forecast_lstm(stock_data, steps=1)
    lstm_forecast_3d = forecast_lstm(stock_data, steps=3)
    lstm_forecast_7d = forecast_lstm(stock_data, steps=7)
    
    print(f"LSTM forecast for {ticker} (1 Day):")
    print(lstm_forecast_1d)
    
    print(f"LSTM forecast for {ticker} (3 Days):")
    print(lstm_forecast_3d)
    
    print(f"LSTM forecast for {ticker} (7 Days):")
    print(lstm_forecast_7d)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: statsmodels in /home/yousafzai/.local/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/yousafzai/.local/lib/python3.10/site-packages (from statsmodels) (2.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /home/yousafzai/.local/lib/python3.10/site-packages (from statsmodels) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /home/yousafzai/.local/lib/python3.10/site-packages (from statsmodels) (24.2)
# Requirement already satisfied: numpy<3,>=1.22.3 in /home/yousafzai/.local/lib/python3.10/site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /usr/lib/python3/dist-packages (from statsmodels) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yousafzai/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/yousafzai/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.2)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/yousafzai/.local/lib/python3.10/site-packages (2.18.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (5.28.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: h5py>=3.11.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: keras>=3.5.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: wrapt>=1.11.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: absl-py>=1.0.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: packaging in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (1.67.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: namex in /home/yousafzai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/yousafzai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.13.0)
# Requirement already satisfied: rich in /home/yousafzai/.local/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/yousafzai/.local/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorflow) (1.26.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.3.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/yousafzai/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/yousafzai/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.8.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/yousafzai/.local/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/yousafzai/.local/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in /home/yousafzai/.local/lib/python3.10/site-packages (0.13.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/lib/python3/dist-packages (from seaborn) (3.5.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/yousafzai/.local/lib/python3.10/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /home/yousafzai/.local/lib/python3.10/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas>=1.2->seaborn) (2022.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/yousafzai/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/yousafzai/.local/lib/python3.10/site-packages (from pandas>=1.2->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2->seaborn) (1.16.0)
#
# Forecasting for META using ARIMA and LSTM:
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ARIMA forecast for META (1 Day):
#             Forecast
# 2021-01-01       NaN
# ARIMA forecast for META (3 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# ARIMA forecast for META (7 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04      NaN
# 2021-01-05      NaN
# 2021-01-06      NaN
# 2021-01-07      NaN
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3841
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0256
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0108
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0164
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0061
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0066
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0065
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0048
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0053
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0049
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0050
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0042
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0036
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0040
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0043
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0041
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0046
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0044
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0052
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.2609
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0269
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0091
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0183
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0068
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0084
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0062
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0055
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0063
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0055
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0054
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0053
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0055
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0052
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0049
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0057
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0043
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0048
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0051
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0062
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.3044
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0255
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0118
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0158
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0093
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0090
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0072
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0063
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0063
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0070
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0066
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0061
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0066
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0058
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0061
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0062
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0071
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# LSTM forecast for META (1 Day):
#               Forecast
# 2021-01-01  276.246887
# LSTM forecast for META (3 Days):
#               Forecast
# 2021-01-01  274.105865
# 2021-01-02  274.028259
# 2021-01-03  273.997681
# LSTM forecast for META (7 Days):
#               Forecast
# 2021-01-01  273.000671
# 2021-01-02  272.903473
# 2021-01-03  272.823853
# 2021-01-04  272.757172
# 2021-01-05  272.700043
# 2021-01-06  272.650177
# 2021-01-07  272.605774
#
# Forecasting for UNH using ARIMA and LSTM:
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ARIMA forecast for UNH (1 Day):
#             Forecast
# 2021-01-01       NaN
# ARIMA forecast for UNH (3 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# ARIMA forecast for UNH (7 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04      NaN
# 2021-01-05      NaN
# 2021-01-06      NaN
# 2021-01-07      NaN
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.1888
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0350
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0147
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0073
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0072
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0050
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0045
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0055
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0041
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0048
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0046
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0044
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0047
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0037
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0042
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0050
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0042
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0045
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0044
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.3622
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0272
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0211
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0145
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0115
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0077
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0069
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0056
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0057
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0057
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0064
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0055
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0053
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0052
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0058
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0060
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0058
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0055
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0051
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.4261
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0352
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0273
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0180
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0122
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0088
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0069
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0082
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0081
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0072
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0071
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0058
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0056
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0065
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0067
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0067
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0061
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0064
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0059
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0058
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# LSTM forecast for UNH (1 Day):
#               Forecast
# 2021-01-01  336.826965
# LSTM forecast for UNH (3 Days):
#               Forecast
# 2021-01-01  339.017548
# 2021-01-02  339.277710
# 2021-01-03  339.346252
# LSTM forecast for UNH (7 Days):
#               Forecast
# 2021-01-01  337.978790
# 2021-01-02  338.214478
# 2021-01-03  338.308960
# 2021-01-04  338.288361
# 2021-01-05  338.182648
# 2021-01-06  338.019196
# 2021-01-07  337.819885
#
# Forecasting for NKE using ARIMA and LSTM:
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ARIMA forecast for NKE (1 Day):
#             Forecast
# 2021-01-01       NaN
# ARIMA forecast for NKE (3 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# ARIMA forecast for NKE (7 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04      NaN
# 2021-01-05      NaN
# 2021-01-06      NaN
# 2021-01-07      NaN
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.3206
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0209
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0104
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0033
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0037
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0026
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0022
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0025
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0023
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0020
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0020
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0019
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0017
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0019
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0019
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0018
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0019
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0017
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.2838
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0262
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0148
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0158
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0082
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0067
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0044
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0039
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0035
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0032
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0029
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0026
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0024
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0022
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0022
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0024
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0020
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0022
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0021
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0020
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.3343
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0381
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0201
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0147
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0081
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0068
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0051
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0054
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0042
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0040
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0033
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0034
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0034
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0036
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0033
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0033
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0036
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0032
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0032
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# LSTM forecast for NKE (1 Day):
#               Forecast
# 2021-01-01  142.583679
# LSTM forecast for NKE (3 Days):
#               Forecast
# 2021-01-01  142.712952
# 2021-01-02  142.959747
# 2021-01-03  143.203751
# LSTM forecast for NKE (7 Days):
#               Forecast
# 2021-01-01  144.180740
# 2021-01-02  144.487610
# 2021-01-03  144.830780
# 2021-01-04  145.198532
# 2021-01-05  145.582535
# 2021-01-06  145.976807
# 2021-01-07  146.377075
#
# Forecasting for CVX using ARIMA and LSTM:
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ARIMA forecast for CVX (1 Day):
#             Forecast
# 2021-01-01       NaN
# ARIMA forecast for CVX (3 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# ARIMA forecast for CVX (7 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04      NaN
# 2021-01-05      NaN
# 2021-01-06      NaN
# 2021-01-07      NaN
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.1675
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0195
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0080
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0110
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0062
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0073
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0060
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0057
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0052
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0048
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0044
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0051
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0044
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0049
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0043
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0040
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0043
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0036
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0038
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.1253
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0238
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0096
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0144
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0076
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0086
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0076
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0065
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0062
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0065
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0066
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0064
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0064
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0065
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0057
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0054
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0059
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0051
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0056
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.1976
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0224
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0148
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0143
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0094
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0095
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0094
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0081
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0092
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0079
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0081
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0085
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0087
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0084
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0078
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0083
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0077
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0077
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0080
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0081
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# LSTM forecast for CVX (1 Day):
#              Forecast
# 2021-01-01  86.009712
# LSTM forecast for CVX (3 Days):
#              Forecast
# 2021-01-01  85.596191
# 2021-01-02  85.378799
# 2021-01-03  85.230614
# LSTM forecast for CVX (7 Days):
#              Forecast
# 2021-01-01  86.188988
# 2021-01-02  86.091217
# 2021-01-03  86.053131
# 2021-01-04  86.051140
# 2021-01-05  86.070755
# 2021-01-06  86.102943
# 2021-01-07  86.141998
#
# Forecasting for AAPL using ARIMA and LSTM:
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ARIMA forecast for AAPL (1 Day):
#             Forecast
# 2021-01-01       NaN
# ARIMA forecast for AAPL (3 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# ARIMA forecast for AAPL (7 Days):
#            Forecast
# 2021-01-01      NaN
# 2021-01-02      NaN
# 2021-01-03      NaN
# 2021-01-04      NaN
# 2021-01-05      NaN
# 2021-01-06      NaN
# 2021-01-07      NaN
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0960
# Epoch 2/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0078
# Epoch 3/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0028
# Epoch 4/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020
# Epoch 5/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0023
# Epoch 6/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019
# Epoch 7/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020
# Epoch 8/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0020
# Epoch 9/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0021
# Epoch 10/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0022
# Epoch 11/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0021
# Epoch 12/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019
# Epoch 13/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.0019
# Epoch 14/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0019
# Epoch 15/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0017
# Epoch 16/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0017
# Epoch 17/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0016
# Epoch 18/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0016
# Epoch 19/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0016
# Epoch 20/20
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0017
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.1855
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0124
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0057
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0029
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0024
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0026
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0025
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0022
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0025
# Epoch 10/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0022
# Epoch 11/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0025
# Epoch 12/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0024
# Epoch 13/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0023
# Epoch 14/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0026
# Epoch 15/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0025
# Epoch 16/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0025
# Epoch 17/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0025
# Epoch 18/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0025
# Epoch 19/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0027
# Epoch 20/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0028
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Epoch 1/20
# /home/yousafzai/.local/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0835
# Epoch 2/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0080
# Epoch 3/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0042
# Epoch 4/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0036
# Epoch 5/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0033
# Epoch 6/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0037
# Epoch 7/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0034
# Epoch 8/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0033
# Epoch 9/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0039
# Epoch 10/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0036
# Epoch 11/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0035
# Epoch 12/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0035
# Epoch 13/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0033
# Epoch 14/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0033
# Epoch 15/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0032
# Epoch 16/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0031
# Epoch 17/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0027
# Epoch 18/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0031
# Epoch 19/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0036
# Epoch 20/20
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0032
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# LSTM forecast for AAPL (1 Day):
#               Forecast
# 2021-01-01  133.342346
# LSTM forecast for AAPL (3 Days):
#               Forecast
# 2021-01-01  129.828598
# 2021-01-02  130.196365
# 2021-01-03  130.414459
# LSTM forecast for AAPL (7 Days):
#               Forecast
# 2021-01-01  126.773788
# 2021-01-02  126.923874
# 2021-01-03  126.865051
# 2021-01-04  126.669060
# 2021-01-05  126.385056
# 2021-01-06  126.045746
# 2021-01-07  125.673012

# %% [markdown]
# # Dynamic Dashboard

# %%
import dash
from dash import dcc, html
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output

# Assuming the stock dataframes are loaded properly and are available in `stock_dataframes`
# Example: stock_dataframes = {'AAPL': pd.DataFrame(...), 'GOOG': pd.DataFrame(...)}

# Sample placeholder functions for ARIMA and LSTM (replace with actual implementations)
def forecast_arima(stock_data, steps):
    # Placeholder for ARIMA forecasting function
    forecast_dates = pd.date_range(start=stock_data.index[-1], periods=steps + 1, freq='D')[1:]
    forecast_values = np.random.randn(steps)  # Replace with actual ARIMA forecast logic
    return pd.DataFrame({'Forecast': forecast_values}, index=forecast_dates)

def forecast_lstm(stock_data, steps):
    # Placeholder for LSTM forecasting function
    forecast_dates = pd.date_range(start=stock_data.index[-1], periods=steps + 1, freq='D')[1:]
    forecast_values = np.random.randn(steps)  # Replace with actual LSTM forecast logic
    return pd.DataFrame({'Forecast': forecast_values}, index=forecast_dates)

# Create the Dash app
app = dash.Dash(__name__)

# Example of available tickers (replace with actual tickers)
selected_tickers = list(stock_dataframes.keys())[:5]  # Limit to first 5 tickers for demonstration

# Create the layout of the dashboard
app.layout = html.Div([
    html.H1('Stock Price Forecasting Dashboard'),

    # Dropdown to select ticker
    html.Div([
        dcc.Dropdown(
            id='ticker-dropdown',
            options=[{'label': ticker, 'value': ticker} for ticker in selected_tickers],
            value=selected_tickers[0],  # Default value
            style={'width': '50%'}
        ),
    ], style={'padding': '10px'}),

    # Dropdown to select forecast type (ARIMA or LSTM)
    html.Div([
        dcc.Dropdown(
            id='forecast-type-dropdown',
            options=[
                {'label': 'ARIMA', 'value': 'ARIMA'},
                {'label': 'LSTM', 'value': 'LSTM'}
            ],
            value='ARIMA',  # Default to ARIMA
            style={'width': '50%'}
        ),
    ], style={'padding': '10px'}),

    # Graphs for forecast (ARIMA or LSTM)
    html.Div([
        dcc.Graph(id='forecast-graph')
    ]),

    # Display Forecasts for 1-day, 3-day, and 7-day
    html.Div([
        html.H3("Forecasts"),
        html.Div(id="forecast-1d"),
        html.Div(id="forecast-3d"),
        html.Div(id="forecast-7d")
    ])
])

# Callback to update the forecast graphs based on selected ticker and forecast type
@app.callback(
    [Output('forecast-graph', 'figure'),
     Output('forecast-1d', 'children'),
     Output('forecast-3d', 'children'),
     Output('forecast-7d', 'children')],
    [Input('ticker-dropdown', 'value'),
     Input('forecast-type-dropdown', 'value')]
)
def update_forecasts(ticker, forecast_type):
    # Get stock data for selected ticker
    stock_data = stock_dataframes[ticker]
    print(f"Stock data for {ticker}:")
    print(stock_data.head())  # Check stock data structure
    
    # Initialize forecast DataFrames for ARIMA and LSTM
    forecast_1d = forecast_3d = forecast_7d = None
    
    # Generate forecasts based on selected forecast type
    if forecast_type == 'ARIMA':
        forecast_1d = forecast_arima(stock_data, steps=1)
        forecast_3d = forecast_arima(stock_data, steps=3)
        forecast_7d = forecast_arima(stock_data, steps=7)
    elif forecast_type == 'LSTM':
        forecast_1d = forecast_lstm(stock_data, steps=1)
        forecast_3d = forecast_lstm(stock_data, steps=3)
        forecast_7d = forecast_lstm(stock_data, steps=7)

    # Debugging prints for forecast data
    print("1 Day Forecast:", forecast_1d.head())
    print("3 Days Forecast:", forecast_3d.head())
    print("7 Days Forecast:", forecast_7d.head())
    
    # Ensure forecast data is not empty or NaN
    if forecast_1d.empty or forecast_3d.empty or forecast_7d.empty:
        print(f"Error: Forecast data for {ticker} is empty.")
        return go.Figure(), "Data not available", "Data not available", "Data not available"

    # Create forecast graph
    forecast_fig = go.Figure()
    forecast_fig.add_trace(go.Scatter(x=forecast_1d.index, y=forecast_1d['Forecast'], mode='lines', name=f'{forecast_type} Forecast (1 Day)'))
    forecast_fig.add_trace(go.Scatter(x=forecast_3d.index, y=forecast_3d['Forecast'], mode='lines', name=f'{forecast_type} Forecast (3 Days)'))
    forecast_fig.add_trace(go.Scatter(x=forecast_7d.index, y=forecast_7d['Forecast'], mode='lines', name=f'{forecast_type} Forecast (7 Days)'))
    forecast_fig.update_layout(title=f'{forecast_type} Forecast for {ticker}', xaxis_title='Date', yaxis_title='Price')

    # Return forecast figure along with numerical results for 1-day, 3-day, and 7-day
    return (
        forecast_fig,
        f"1 Day: {forecast_1d['Forecast'].iloc[0]:.2f}",
        f"3 Days: {forecast_3d['Forecast'].iloc[2]:.2f}",
        f"7 Days: {forecast_7d['Forecast'].iloc[6]:.2f}"
    )

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Stock data for META:
#         date       Close ticker  sentiment
# 0 2019-12-31  205.250000   META        NaN
# 1 2020-01-02  209.779999   META        NaN
# 2 2020-01-03  208.669998   META        NaN
# 3 2020-01-06  212.600006   META        NaN
# 4 2020-01-07  213.059998   META        NaN
# 1 Day Forecast:                                Forecast
# 1970-01-02 00:00:00.000000253  0.199267
# 3 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000253 -1.081927
# 1970-01-03 00:00:00.000000253  1.003465
# 1970-01-04 00:00:00.000000253  1.106151
# 7 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000253  0.135914
# 1970-01-03 00:00:00.000000253 -0.112316
# 1970-01-04 00:00:00.000000253  0.157987
# 1970-01-05 00:00:00.000000253 -0.443866
# 1970-01-06 00:00:00.000000253  1.039403
# Stock data for UNH:
#         date       Close ticker  sentiment
# 0 2019-12-31  293.980011    UNH        NaN
# 1 2020-01-02  292.500000    UNH        NaN
# 2 2020-01-03  289.540009    UNH        NaN
# 3 2020-01-06  291.549988    UNH        NaN
# 4 2020-01-07  289.790009    UNH        NaN
# 1 Day Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254  0.559855
# 3 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254 -0.276893
# 1970-01-03 00:00:00.000000254  2.257809
# 1970-01-04 00:00:00.000000254 -1.943613
# 7 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254  0.667410
# 1970-01-03 00:00:00.000000254  1.656934
# 1970-01-04 00:00:00.000000254  1.656960
# 1970-01-05 00:00:00.000000254  0.448357
# 1970-01-06 00:00:00.000000254 -0.274997
# Stock data for UNH:
#         date       Close ticker  sentiment
# 0 2019-12-31  293.980011    UNH        NaN
# 1 2020-01-02  292.500000    UNH        NaN
# 2 2020-01-03  289.540009    UNH        NaN
# 3 2020-01-06  291.549988    UNH        NaN
# 4 2020-01-07  289.790009    UNH        NaN
# 1 Day Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254  0.848083
# 3 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254  1.145155
# 1970-01-03 00:00:00.000000254 -0.991712
# 1970-01-04 00:00:00.000000254 -1.604430
# 7 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000254 -0.743406
# 1970-01-03 00:00:00.000000254 -0.846729
# 1970-01-04 00:00:00.000000254 -0.843051
# 1970-01-05 00:00:00.000000254  0.781120
# 1970-01-06 00:00:00.000000254  1.983562
# Stock data for AAPL:
#         date      Close ticker  sentiment
# 0 2019-12-31  73.412498   AAPL        NaN
# 1 2020-01-02  75.087502   AAPL     0.9153
# 2 2020-01-02  75.087502   AAPL     0.4874
# 3 2020-01-02  75.087502   AAPL     0.9507
# 4 2020-01-03  74.357498   AAPL     0.1280
# 1 Day Forecast:                                Forecast
# 1970-01-02 00:00:00.000000637  1.008533
# 3 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000637 -0.109363
# 1970-01-03 00:00:00.000000637  1.109722
# 1970-01-04 00:00:00.000000637 -0.202650
# 7 Days Forecast:                                Forecast
# 1970-01-02 00:00:00.000000637 -1.272602
# 1970-01-03 00:00:00.000000637  1.006517
# 1970-01-04 00:00:00.000000637 -3.576076
# 1970-01-05 00:00:00.000000637 -0.387357
# 1970-01-06 00:00:00.000000637 -1.056853
